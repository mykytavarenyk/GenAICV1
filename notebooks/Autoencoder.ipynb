# %%
# !pip install torch torchvision tensorboard tqdm matplotlib numpy
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.68.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboard) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)

# %%
# main.py

import torch
import numpy as np

from data.datasets import get_cifar10_dataloaders
from models.autoencoder import Autoencoder
from utils.train import train_model
from PIL import Image


torch.manual_seed(42)
np.random.seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

    # Hyperparameters
num_epochs = 20
batch_size = 32
learning_rate = 1e-3
    # Get DataLoaders
train_loader, val_loader, test_loader = get_cifar10_dataloaders(
        batch_size=batch_size,
        validation_split=0.2,
        num_workers=4,
        download=True,
        normalize=False
)


model = Autoencoder()

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)


train_model(
    model,
    train_loader,
    val_loader,
    optimizer,
    num_epochs,
    device,
    model_name='Autoencoder',
    denorm_params=None,  
    generate_images_flag=False  
)
# Out:
# Using device: cuda
# Files already downloaded and verified
# Files already downloaded and verified
# Training Epoch 1/20: 100%|██████████| 1250/1250 [00:07<00:00, 157.24it/s, Loss=0.00802]
# Epoch [1/20], Training Loss: 0.013863, Validation Loss: 0.007634
# Best model saved with validation loss: 0.007634
# Training Epoch 2/20: 100%|██████████| 1250/1250 [00:07<00:00, 161.96it/s, Loss=0.00573]
# Epoch [2/20], Training Loss: 0.006512, Validation Loss: 0.005690
# Best model saved with validation loss: 0.005690
# Training Epoch 3/20: 100%|██████████| 1250/1250 [00:07<00:00, 160.09it/s, Loss=0.00518]
# Epoch [3/20], Training Loss: 0.005183, Validation Loss: 0.005086
# Best model saved with validation loss: 0.005086
# Training Epoch 4/20: 100%|██████████| 1250/1250 [00:07<00:00, 157.43it/s, Loss=0.00388]
# Epoch [4/20], Training Loss: 0.004536, Validation Loss: 0.004268
# Best model saved with validation loss: 0.004268
# Training Epoch 5/20: 100%|██████████| 1250/1250 [00:07<00:00, 157.40it/s, Loss=0.00474]
# Epoch [5/20], Training Loss: 0.004160, Validation Loss: 0.004170
# Best model saved with validation loss: 0.004170
# Training Epoch 6/20: 100%|██████████| 1250/1250 [00:07<00:00, 166.51it/s, Loss=0.0034]
# Epoch [6/20], Training Loss: 0.003729, Validation Loss: 0.003379
# Best model saved with validation loss: 0.003379
# Training Epoch 7/20: 100%|██████████| 1250/1250 [00:07<00:00, 162.22it/s, Loss=0.00357]
# Epoch [7/20], Training Loss: 0.003221, Validation Loss: 0.003301
# Best model saved with validation loss: 0.003301
# Training Epoch 8/20: 100%|██████████| 1250/1250 [00:07<00:00, 161.74it/s, Loss=0.00263]
# Epoch [8/20], Training Loss: 0.002983, Validation Loss: 0.002916
# Best model saved with validation loss: 0.002916
# Training Epoch 9/20: 100%|██████████| 1250/1250 [00:07<00:00, 167.68it/s, Loss=0.00261]
# Epoch [9/20], Training Loss: 0.002812, Validation Loss: 0.002761
# Best model saved with validation loss: 0.002761
# Training Epoch 10/20: 100%|██████████| 1250/1250 [00:07<00:00, 164.04it/s, Loss=0.00231]
# Epoch [10/20], Training Loss: 0.002678, Validation Loss: 0.002603
# Best model saved with validation loss: 0.002603
# Training Epoch 11/20: 100%|██████████| 1250/1250 [00:07<00:00, 160.25it/s, Loss=0.00292]
# Epoch [11/20], Training Loss: 0.002573, Validation Loss: 0.002727
# Training Epoch 12/20: 100%|██████████| 1250/1250 [00:07<00:00, 159.56it/s, Loss=0.00226]
# Epoch [12/20], Training Loss: 0.002457, Validation Loss: 0.002395
# Best model saved with validation loss: 0.002395
# Training Epoch 13/20: 100%|██████████| 1250/1250 [00:07<00:00, 165.12it/s, Loss=0.0028]
# Epoch [13/20], Training Loss: 0.002343, Validation Loss: 0.002571
# Training Epoch 14/20: 100%|██████████| 1250/1250 [00:07<00:00, 160.85it/s, Loss=0.00226]
# Epoch [14/20], Training Loss: 0.002220, Validation Loss: 0.002129
# Best model saved with validation loss: 0.002129
# Training Epoch 15/20: 100%|██████████| 1250/1250 [00:07<00:00, 161.83it/s, Loss=0.00237]
# Epoch [15/20], Training Loss: 0.002113, Validation Loss: 0.002048
# Best model saved with validation loss: 0.002048
# Training Epoch 16/20: 100%|██████████| 1250/1250 [00:07<00:00, 165.44it/s, Loss=0.00183]
# Epoch [16/20], Training Loss: 0.002034, Validation Loss: 0.002079
# Training Epoch 17/20: 100%|██████████| 1250/1250 [00:07<00:00, 163.28it/s, Loss=0.002]
# Epoch [17/20], Training Loss: 0.001965, Validation Loss: 0.001945
# Best model saved with validation loss: 0.001945
# Training Epoch 18/20: 100%|██████████| 1250/1250 [00:07<00:00, 161.86it/s, Loss=0.00211]
# Epoch [18/20], Training Loss: 0.001893, Validation Loss: 0.002066
# Training Epoch 19/20: 100%|██████████| 1250/1250 [00:07<00:00, 163.80it/s, Loss=0.0017]
# Epoch [19/20], Training Loss: 0.001842, Validation Loss: 0.001815
# Best model saved with validation loss: 0.001815
# Training Epoch 20/20: 100%|██████████| 1250/1250 [00:07<00:00, 161.92it/s, Loss=0.00188]
# Epoch [20/20], Training Loss: 0.001784, Validation Loss: 0.001734
# Best model saved with validation loss: 0.001734

# %%
from PIL import Image

image_path = "../images/Autoencoder/reconstructions_epoch_20.png"
image = Image.open(image_path)

image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=266x138>
